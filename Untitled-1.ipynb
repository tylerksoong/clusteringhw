# %%
from cluster_pipeline import pipeline, X

# %%
df = pipeline(X, 4)
# Out:
#           0         1  cluster_labels  hierarchal_labels
# 0  0.836857  2.136359               3                  2
# 1 -1.413658  7.409623               0                  1
# 2  1.155213  5.099619               1                  4
# 3 -1.018616  7.814915               0                  1
# 4  1.271351  1.892542               3                  2
